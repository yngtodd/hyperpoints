# %%
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
run0 = pd.read_csv('progress0.csv')
run1 = pd.read_csv('progress1.csv')
run2 = pd.read_csv('progress2.csv')
run3 = pd.read_csv('progress3.csv')
run4 = pd.read_csv('progress4.csv')

# %%
run0.iloc[0]
# Out:
# advantage_norm            2.994657
# policy_loss               0.080110
# frames                 8000.000000
# explained_variance       -7.866783
# PMM:episode_rewards       1.170732
# fps                    1212.000000
# value_loss                0.263957
# episode_length          171.658537
# P09:episode_rewards       2.000000
# grad_norm                 9.579488
# epoch_idx                 1.000000
# policy_entropy            1.329574
# P01:episode_rewards       0.000000
# Name: 0, dtype: float64

# %%
runs = [run0, run1, run2, run3, run4]

# %%
rewards = [np.array(x['PMM:episode_rewards']) for x in runs]

# %%
rewards[0].shape
# Out:
# (1375,)

# %%
df = pd.concat([pd.Series(x) for x in rewards], axis=1)

# %%
df.shape
# Out:
# (1375, 5)

# %%
def plot_average_walks(walks):
    """Plot aggregate results of series.
    
    Parameters
    ----------
    walks : pd.DataFrame
      Dataframe containing random walks as columns.
    """
    mean = np.array(walks.mean(axis=1))
    std_dev = np.array(walks.std(axis=1))
    upper = mean + std_dev
    lower = mean - std_dev
    results = [upper, mean, lower]
    sns.tsplot(results)

# %%
plot_average_walks(df)
